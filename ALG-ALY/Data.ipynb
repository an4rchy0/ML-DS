# %%
import pandas as pd

data = {
    'province'           : ['Aceh', 'Aceh', 'Jakarta', 'Jakarta', 'Jabar', 'Jabar', 'Jabar', 'Jateng', 'Jateng', 'Kalbar'],
    'citiesReg'          : ['Banda Aceh', 'Sabang', 'Jakarta Timur', 'Jakarta Selatan', 'Bogor', 'Sukabumi', 'Bandung', 'Semarang', 'Brebes', 'Pontianak'],
    'poor%'              : [7.61, 15.32, 4.28, 3.56, 8.13, 7.7, 7.15, 7.82, 17.43, 5.18],
    'regGDP'             : [18.28, 1.53, 470.99, 644.57, 236.14, 67.39, 123.04, 49.03, 47.14, 8.54],
    'lifeExp'            : [71.47, 70.50, 74.48, 74.22, 71.38, 71.2, 73.73, 75.84, 69.54, 71.09],
    'avgSchoolTime'      : [12.83, 11.18, 11.67, 11.64, 8.31, 7.1, 9.07, 8.03, 6.22, 7.04],
    'expPercap'          : [16891, 11378, 17733, 23888, 10410, 8850, 10307, 12070, 10152, 7758]
}

dataDF = pd.DataFrame(data)
dataDF
# Out:
#   province        citiesReg  poor%  regGDP  lifeExp  avgSchoolTime  expPercap
# 0     Aceh       Banda Aceh   7.61   18.28    71.47          12.83      16891
# 1     Aceh           Sabang  15.32    1.53    70.50          11.18      11378
# 2  Jakarta    Jakarta Timur   4.28  470.99    74.48          11.67      17733
# 3  Jakarta  Jakarta Selatan   3.56  644.57    74.22          11.64      23888
# 4    Jabar            Bogor   8.13  236.14    71.38           8.31      10410
# 5    Jabar         Sukabumi   7.70   67.39    71.20           7.10       8850
# 6    Jabar          Bandung   7.15  123.04    73.73           9.07      10307
# 7   Jateng         Semarang   7.82   49.03    75.84           8.03      12070
# 8   Jateng           Brebes  17.43   47.14    69.54           6.22      10152
# 9   Kalbar        Pontianak   5.18    8.54    71.09           7.04       7758

# %%
dataDF = dataDF.sort_values(by='poor%')
dataDF

# %%
dataDF = dataDF.sort_values(by='poor%', ascending=False)
dataDF

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for pr, d in dataDF.groupby('poor%'):
    ax.scatter(d['citiesReg'], d['poor%'], label=pr)

plt.title('Poor Region Rank')
plt.xlabel('Cities Region')
plt.ylabel('Poor Percentage (%)')
plt.grid(True)
ax.tick_params(axis='x', labelsize=8)
plt.xticks(rotation=45)
plt.show()
